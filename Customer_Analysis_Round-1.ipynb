# %%
import pandas as pd
file1 = pd.read_csv('files_for_lab/csv_files/file1.csv')
file2 = pd.read_csv('files_for_lab/csv_files/file2.csv')
file3 = pd.read_csv('files_for_lab/csv_files/file3.csv')

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file1.rename(
    columns={"ST": "State",
             "GENDER": "Gender"}, inplace=True)
             
file2.rename(
    columns={"ST": "State",
             "GENDER": "Gender"}
          ,inplace=True)   
file2
# Out:
#     Customer       State Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file2 = file2[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

file3 = file3[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

# %%
file = pd.concat([file1, file2, file3], axis=0)
file.shape
# Out:
# (12074, 11)

# %%
file.dtypes
# Out:
# Customer                      object
# State                         object
# Gender                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
file._get_numeric_data()
# Out:
#        Income  Monthly Premium Auto  Total Claim Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
# Categorical: all but the numerical and 'Customer'

# %%
file = file.drop(['Education', 'Number of Open Complaints'], axis=1)

# %%
file
# Out:
#      Customer       State Gender Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                   23406  71941.0
# 7066  PK87824  California      F                 3096.51  21604.0
# 7067  TD14365  California      M                 8163.89      0.0
# 7068  UP19263  California      M                 7524.44  21941.0
# 7069  Y167826  California      M                 2611.84      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
file['Customer Lifetime Value'] = file['Customer Lifetime Value'].str.replace('%','')
file
# Out:
#      Customer       State Gender Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F               697953.59      0.0
# 2     AI49188      Nevada      F              1288743.17  48767.0
# 3     WW63253  California      M               764586.18      0.0
# 4     GA49547  Washington      M               536307.65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                     NaN  71941.0
# 7066  PK87824  California      F                     NaN  21604.0
# 7067  TD14365  California      M                     NaN      0.0
# 7068  UP19263  California      M                     NaN  21941.0
# 7069  Y167826  California      M                     NaN      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
file['Customer Lifetime Value'] = file['Customer Lifetime Value'].str.replace('%','')

# %%
file['Customer Lifetime Value'] =  pd.to_numeric(file['Customer Lifetime Value'], errors='coerce')
file.dtypes
# Out:
# Customer                    object
# State                       object
# Gender                      object
# Customer Lifetime Value    float64
# Income                     float64
# Monthly Premium Auto       float64
# Policy Type                 object
# Vehicle Class               object
# Total Claim Amount         float64
# dtype: object

# %%
file['Customer Lifetime Value'] = list(map(lambda x: x/10000, file['Customer Lifetime Value']))

# %%
file
# Out:
#      Customer       State Gender  Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                69.795359      0.0
# 2     AI49188      Nevada      F               128.874317  48767.0
# 3     WW63253  California      M                76.458618      0.0
# 4     GA49547  Washington      M                53.630765  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                      NaN  71941.0
# 7066  PK87824  California      F                      NaN  21604.0
# 7067  TD14365  California      M                      NaN      0.0
# 7068  UP19263  California      M                      NaN  21941.0
# 7069  Y167826  California      M                      NaN      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
filecopy = file.copy()
filecopy = filecopy.drop_duplicates()
print(filecopy.shape)
print(file.shape)
# Out:
# (9131, 9)
# (12074, 9)

# %%
filecopy['belowzero'] = filecopy['Income'] < 20000
filecopy
# Out:
#      Customer       State Gender  Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                 0.006980      0.0
# 2     AI49188      Nevada      F                 0.012887  48767.0
# 3     WW63253  California      M                 0.007646      0.0
# 4     GA49547  Washington      M                 0.005363  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                      NaN  71941.0
# 7066  PK87824  California      F                      NaN  21604.0
# 7067  TD14365  California      M                      NaN      0.0
# 7068  UP19263  California      M                      NaN  21941.0
# 7069  Y167826  California      M                      NaN      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
filecopy[filecopy['belowzero'] == True]
# Out:
#      Customer       State Gender  Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                 0.006980      0.0
# 3     WW63253  California      M                 0.007646      0.0
# 7     CF85061     Arizona      M                 0.007216      0.0
# 8     DY87989      Oregon      M                 0.024128  14072.0
# ...       ...         ...    ...                      ...      ...
# 7059  WZ45103  California      F                      NaN      0.0
# 7061  RX91025  California      M                      NaN      0.0
# 7062  AC13887  California      M                      NaN      0.0
# 7067  TD14365  California      M                      NaN      0.0
# 7069  Y167826  California      M                      NaN      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
